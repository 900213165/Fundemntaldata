# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic

# %%
import seaborn as sns

# %%
import openpyxl

# %%
df= pd.read_csv(r"c:\Users\MARWAN\OneDrive\Documents\marketing_data.csv")

# %%
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0   6/16/2014        0       189  ...                  6
# 1         0   6/15/2014        0       464  ...                  7
# 2         1   5/13/2014        0       134  ...                  5
# 3         1   5/11/2014        0        10  ...                  2
# 4         0    4/8/2014        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
pd.isnull(df).sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head(3)
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0   6/16/2014        0       189  ...                  6
# 1         0   6/15/2014        0       464  ...                  7
# 2         1   5/13/2014        0       134  ...                  5
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# 1                  5             0             0             0             0
# 2                  2             0             0             0             0
#
#    AcceptedCmp2  Response  Complain  Country
# 0             0         1         0       SP
# ...

# %%
pd.isnull(df).sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
#  Income                0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2216.000000  2216.000000  2216.000000  2216.000000  2216.000000
# mean    5588.353339  1968.820397     0.441787     0.505415    49.012635
# std     3249.376275    11.985554     0.536896     0.544181    28.948352
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2814.750000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8421.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2216.000000  2216.000000      2216.000000      2216.000000
# mean    305.091606    26.356047       166.995939        37.637635
# std     337.327920    39.793917       224.283273        54.752082
# ...

# %%
df.head(3)
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0   6/16/2014        0       189  ...                  6
# 1         0   6/15/2014        0       464  ...                  7
# 2         1   5/13/2014        0       134  ...                  5
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# 1                  5             0             0             0             0
# 2                  2             0             0             0             0
#
#    AcceptedCmp2  Response  Complain  Country
# 0             0         1         0       SP
# ...

# %%
df[' Income '] = df[' Income '].str.replace("[$,]","").astype(float)
# Out:
# C:\Users\MARWAN\AppData\Local\Temp/ipykernel_14400/1029055254.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[' Income '] = df[' Income '].str.replace("[$,]","").astype(float)

# %%
df["age"]=2022-df['Year_Birth']

# %%
 df.iloc[:, 9:15].columns
# Out:
# Index(['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds'],
#       dtype='object')

# %%
df['pruchases_total']= df.iloc[:, 9:15].sum(axis=1)

# %%
product_cols = ['MntWines', 'MntFruits','MntMeatProducts', 'MntFishProducts', 'MntSweetProducts','MntGoldProds']

plt.figure(figsize=(10,5))
plt.bar(x=product_cols, height=df[product_cols].sum(),)
plt.title("Total Amount Ordered in the Last 2 Years")
plt.ylabel("Quantity")
# Out:
# Text(0, 0.5, 'Quantity')

# %% [markdown]
# This bar chart shows the total amount spent on each product over the past 2 years, it can be seen that wines consititued the largest part of the companys sale over the past 2 years, followed by meat products with a relatively big gap between them. The remaining three products got almost the same sales over 2 years.

# %%
df2=pd.DataFrame(df.iloc[:,20:25].sum(),  columns=['total accepted']).reset_index()
df2
plt.figure(figsize=(10,5))
plt.bar(x=df2["index"],height=df2["total accepted"])
plt.xlabel("campgain")
plt.ylabel("total accepted")
plt.title("campigan sucess")
# Out:
# Text(0.5, 1.0, 'campigan sucess')

# %% [markdown]
# This bar chart visulizes the sucess of each the five camgians it can be seen that the fourth campigan is the most sucessfull of the five closely followed by the 3 and then the 5 fifth. The secoend campigan byfar preformed the worst in betweeen the five.

# %%
plt.bar(x=['NumWebPurchases','NumCatalogPurchases', 'NumStorePurchases'],  
        height=df[['NumWebPurchases','NumCatalogPurchases', 'NumStorePurchases']].sum(),)
# Out:
# <BarContainer object of 3 artists>

# %%
The bar chart showed that the majority of sales came through the companyys store follwed by website and
finally the company acquired the least sales through their catlog.

# %%
df['Country'].value_counts().plot(kind="bar",xlabel="country",title="number of customers per country")
# Out:
# <AxesSubplot:title={'center':'number of customers per country'}, xlabel='country'>

# %%
grouped=df.groupby("Country")
grouped['pruchases_total'].sum().plot(kind="barh",title="total purchases per country",xlabel="country",ylabel="toal")
# Out:
# <AxesSubplot:title={'center':'total purchases per country'}, ylabel='country'>

# %% [markdown]
# In this bar plot it canbe seen that the distrubition of total sales follows that of countries with the most countries,
# higher number of customers, higher sales

# %%
df['Education'].value_counts(normalize=True).plot(kind='pie', title='Clients Education')
# Out:
# <AxesSubplot:title={'center':'Clients Education'}, ylabel='Education'>

# %% [markdown]
# In this pie chart it can be seen that the majority of clients have graduted from universty and have not continued their education while more than third of the clients have either a masters degeree of a PHD

# %%
df['Marital_Status'].value_counts().plot(kind="pie",title="Martial status")
# Out:
# <AxesSubplot:ylabel='Marital_Status'>

# %%
df["age"].plot(kind="density", title="age distrubtion").set_xlim(10, 90)
# Out:
# (10.0, 90.0)

# %%
In this desnirty plot it can be seen that the majority of the clients of the compay are in their foutys and fifties, and the
majprity of the clienst are older than 40

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=df['NumWebVisitsMonth'],y=df['NumWebPurchases'])
plt.xlabel("Number Web visits ")
plt.ylabel("Number web purchases")
plt.title("Relation between web visits and web purchases")
# Out:
# Text(0.5, 1.0, 'Relation between web visits and web purchases')

# %%
df[['NumWebVisitsMonth','NumWebPurchases']].corr(method='pearson')

# %% [markdown]
# As shown by the corealtion coeffceint and scatter plot,
# there is no linear realtion between number of web visits per month and web purchases

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=df['NumWebVisitsMonth'],y=df['NumCatalogPurchases'])
plt.xlabel("Number Web visits ")
plt.ylabel("Number catalog purchases")
plt.title("Relation between web visits and catalog purchases")
# Out:
# Text(0.5, 1.0, 'Relation between web visits and catalog purchases')

# %%
df[['NumWebVisitsMonth','NumCatalogPurchases']].corr(method='pearson')
# Out:
#                      NumWebVisitsMonth  NumCatalogPurchases
# NumWebVisitsMonth             1.000000            -0.522004
# NumCatalogPurchases          -0.522004             1.000000

# %% [markdown]
# There is a negative realtion between the number of visits to the company website and the number of catalog sales

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=df[' Income '],y=df['MntGoldProds'])
plt.xlabel("Income ")
plt.ylabel("Amount spent on gold")
plt.title("Relation between income and gold purchases")
# Out:
# Text(0.5, 1.0, 'Relation between income and gold purchases')

# %%
df[[' Income ','MntGoldProds']].corr(method='pearson')

# %% [markdown]
# As shown by the scatter plot and corealtion coefficent,
# there is a very weak linear relationship between income and amount spent on gold

# %%
grouped=df.groupby("Country").mean()

# %%
grouped
# Out:
#                   ID   Year_Birth       Income    Kidhome  Teenhome  \
# Country
# AUS      5651.639456  1967.748299  51804.285714  0.496599  0.517007
# CA       5757.172932  1968.127820  53050.616541  0.421053  0.552632
# GER      4941.629310  1968.853448  52951.094828  0.379310  0.448276
# IND      5564.054422  1970.918367  49016.414966  0.523810  0.496599
# ME       5774.333333  1972.333333  57680.333333  0.000000  0.666667
# SA       5700.192878  1969.181009  54830.816024  0.486647  0.477745
# SP       5563.742909  1968.785910  51564.577310  0.426349  0.506862
# US       5710.168224  1968.214953  53218.373832  0.401869  0.514019
#
#            Recency    MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Country
# AUS      44.836735  290.829932  25.095238       151.891156        37.727891
# CA       46.729323  316.037594  28.875940       172.650376        37.518797
# GER      49.715517  317.034483  25.689655       174.758621        39.663793
# ...

# %%
subset=df.loc[(df['Education'] == "Phd") | (df['Education'] =="Masters")]

# %%
grouped = subset.groupby('Kidhome')

# %%
grouped['Education'].value_counts().unstack().plot(kind="barh")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14400/2642452497.py in <module>
# ----> 1 grouped['Education'].value_counts().unstack().plot(kind="barh")
#
# C:\R and R studio\anaconda3.0\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# C:\R and R studio\anaconda3.0\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
y=df[['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
       'AcceptedCmp2']].corr().round(2)
y
# Out:
#               AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# AcceptedCmp3          1.00         -0.08          0.08          0.10
# AcceptedCmp4         -0.08          1.00          0.31          0.24
# AcceptedCmp5          0.08          0.31          1.00          0.41
# AcceptedCmp1          0.10          0.24          0.41          1.00
# AcceptedCmp2          0.07          0.30          0.22          0.18
#
#               AcceptedCmp2
# AcceptedCmp3          0.07
# AcceptedCmp4          0.30
# AcceptedCmp5          0.22
# AcceptedCmp1          0.18
# AcceptedCmp2          1.00

# %%
sns.heatmap(y, annot=True)
# Out:
# <AxesSubplot:>

# %%
The heat map shows that there are no ccorelotions between customers accepting the offers

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country', 'age',
#        'pruchases_total'],
#       dtype='object')

# %%
freq0={"kids at home":df['Kidhome'].value_counts(normalize=True), "Teen home":df['Teenhome'].value_counts(normalize=True)}
freq0df=pd.DataFrame(freq0)
freq0df
# Out:
#    kids at home  Teen home
# 0      0.578971   0.517599
# 1      0.400271   0.459386
# 2      0.020758   0.023014

# %%
The majority of customers do not have any children, with very few having 2 
Almost half of the customers have no teens at home, while the other half one with ver g]few having 2

# %%
freq={'AcceptedCmp1':df['AcceptedCmp1'].value_counts(normalize=True),'AcceptedCmp2':df["AcceptedCmp2"].value_counts(normalize=True),
'AcceptedCmp3':df['AcceptedCmp3'].value_counts(normalize=True), 'AcceptedCmp4':df['AcceptedCmp4'].value_counts(normalize=True),
'AcceptedCmp5':df['AcceptedCmp5'].value_counts(normalize=True), 'Response':df['Response'].value_counts(normalize=True),
'Complain':df['Complain'].value_counts(normalize=True)}

freqdf=pd.DataFrame(freq)
freqdf
# Out:
#    AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0      0.935921      0.986462      0.926444      0.925993      0.926895
# 1      0.064079      0.013538      0.073556      0.074007      0.073105
#
#    Response  Complain
# 0  0.849729  0.990523
# 1  0.150271  0.009477

# %% [markdown]
# This df shows the precentge of customers that has accepted an offer

# %%
pd.crosstab(df['Complain'],df['AcceptedCmp1'])
# Out:
# AcceptedCmp1     0    1
# Complain
# 0             2053  142
# 1               21    0

# %%
pd.crosstab(df['Complain'],df['AcceptedCmp2'])
# Out:
# AcceptedCmp2     0   1
# Complain
# 0             2165  30
# 1               21   0

# %%
pd.crosstab(df['Complain'],df['AcceptedCmp3'])
# Out:
# AcceptedCmp3     0    1
# Complain
# 0             2034  161
# 1               19    2

# %%
pd.crosstab(df['Complain'],df['AcceptedCmp4'])
# Out:
# AcceptedCmp4     0    1
# Complain
# 0             2031  164
# 1               21    0

# %%
pd.crosstab(df['Complain'],df['AcceptedCmp5'])
# Out:
# AcceptedCmp5     0    1
# Complain
# 0             2034  161
# 1               20    1

# %%
pd.crosstab(df['Complain'],df['Education'])
# Out:
# Education  2n Cycle  Basic  Graduation  Master  PhD
# Complain
# 0               196     54        1102     363  480
# 1                 4      0          14       2    1

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country', 'age',
#        'pruchases_total'],
#       dtype='object')

# %%
pd.crosstab(df['Kidhome'],df['Teenhome'])
# Out:
# Teenhome    0    1   2
# Kidhome
# 0         633  620  30
# 1         497  369  21
# 2          17   29   0

# %%
df.corr()
# Out:
#                            ID  Year_Birth   Kidhome  Teenhome   Recency  \
# ID                   1.000000    0.002355  0.001736 -0.003030 -0.044376
# Year_Birth           0.002355    1.000000  0.233615 -0.350791 -0.016295
# Kidhome              0.001736    0.233615  1.000000 -0.039869  0.011492
# Teenhome            -0.003030   -0.350791 -0.039869  1.000000  0.013838
# Recency             -0.044376   -0.016295  0.011492  0.013838  1.000000
# MntWines            -0.021084   -0.159451 -0.497336  0.003747  0.015721
# MntFruits            0.007326   -0.017747 -0.373396 -0.176558 -0.005844
# MntMeatProducts     -0.005902   -0.033697 -0.439261 -0.261122  0.022518
# MntFishProducts     -0.023992   -0.040425 -0.388884 -0.205242  0.000551
# MntSweetProducts    -0.005936   -0.020204 -0.378026 -0.163056  0.025110
# MntGoldProds        -0.011172   -0.064208 -0.355029 -0.019887  0.017663
# NumDealsPurchases   -0.040612   -0.058668  0.216913  0.386246  0.002115
# ...

# %%
mosaic(df,['Country','Response'],title="Country X Response")
plt.rcParams["figure.figsize"]=(20,5)
plt.show()

# %%
mosaic(df,['Country','Education'],title="Country X Education")
plt.rcParams["figure.figsize"]=(20,5)
plt.show()
